# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Read data
train = pd.read_csv('datasets/titanic/train.csv')
test = pd.read_csv('datasets/titanic/test.csv')

# %% [markdown]
# ### I. Exploration

# %% [markdown]
# Clean the training data and test data separately.

# %%
print('Train data shape: ', train.shape)
train.head()
# Out:
# ('Train data shape: ', (891, 12))
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print('Test data shape: ', test.shape)
# Out:
# ('Test data shape: ', (418, 11))

# %%
train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Graham, Mr. George Edward  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare        Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000          204
# unique         NaN         NaN         NaN       681         NaN          147
# top            NaN         NaN         NaN  CA. 2343         NaN  C23 C25 C27
# freq           NaN         NaN         NaN         7         NaN            4
# mean     29.699118    0.523008    0.381594       NaN   32.204208          NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429          NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000          NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400          NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200          NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000          NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200          NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
test.describe(include='all')
# Out:
#         PassengerId      Pclass                           Name   Sex  \
# count    418.000000  418.000000                            418   418
# unique          NaN         NaN                            418     2
# top             NaN         NaN  Rosenbaum, Miss. Edith Louise  male
# freq            NaN         NaN                              1   266
# mean    1100.500000    2.265550                            NaN   NaN
# std      120.810458    0.841838                            NaN   NaN
# min      892.000000    1.000000                            NaN   NaN
# 25%      996.250000    1.000000                            NaN   NaN
# 50%     1100.500000    3.000000                            NaN   NaN
# 75%     1204.750000    3.000000                            NaN   NaN
# max     1309.000000    3.000000                            NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# unique         NaN         NaN         NaN       363         NaN
# top            NaN         NaN         NaN  PC 17608         NaN
# freq           NaN         NaN         NaN         5         NaN
# mean     30.272590    0.447368    0.392344       NaN   35.627188
# std      14.181209    0.896760    0.981429       NaN   55.907576
# min       0.170000    0.000000    0.000000       NaN    0.000000
# 25%      21.000000    0.000000    0.000000       NaN    7.895800
# 50%      27.000000    0.000000    0.000000       NaN   14.454200
# 75%      39.000000    1.000000    0.000000       NaN   31.500000
# max      76.000000    8.000000    9.000000       NaN  512.329200
#
#                   Cabin Embarked
# count                91      418
# unique               76        3
# top     B57 B59 B63 B66        S
# freq                  3      270
# mean                NaN      NaN
# std                 NaN      NaN
# min                 NaN      NaN
# 25%                 NaN      NaN
# 50%                 NaN      NaN
# 75%                 NaN      NaN
# max                 NaN      NaN

# %% [markdown]
# <b>Missing data from Training and Test</b>

# %%
# Get missing data info for each feature
train_missing = train.isnull().sum()
test_missing = test.isnull().sum()

pd.concat([train_missing, test_missing], axis=1, keys=['Training', 'Test']).sort_values(by='Training', ascending=False)
# Out:
#              Training   Test
# Cabin             687  327.0
# Age               177   86.0
# Embarked            2    0.0
# Fare                0    1.0
# Name                0    0.0
# Parch               0    0.0
# PassengerId         0    0.0
# Pclass              0    0.0
# Sex                 0    0.0
# SibSp               0    0.0
# Survived            0    NaN
# Ticket              0    0.0

# %% [markdown]
# <h4>Estimating the missing Age data</h4>

# %%
all_data = pd.concat([train, test], axis=0, ignore_index=True).sort_values(by='PassengerId')
pd.concat([all_data['Name'], all_data['Age']], axis=1).head(7)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0

# %%
all_data['Title'] = all_data['Name'].str.extract('([A-Za-z]+)\.')
orig_titles = all_data['Title'].unique()
orig_titles
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %%
new_titles = ['Mr', 'Mrs', 'Ms', 'Child', 'Mr', 'Mr', 'Mr', 'Ms', 'Ms', 'Mr', 'Ms', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mrs']
all_data['Title'].replace(orig_titles, new_titles, inplace=True)
pd.concat([all_data['Name'], all_data['Age'], all_data['Title']], axis=1).head(7)
# Out:
#                                                 Name   Age Title
# 0                            Braund, Mr. Owen Harris  22.0    Mr
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   Mrs
# 2                             Heikkinen, Miss. Laina  26.0    Ms
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0   Mrs
# 4                           Allen, Mr. William Henry  35.0    Mr
# 5                                   Moran, Mr. James   NaN    Mr
# 6                            McCarthy, Mr. Timothy J  54.0    Mr

# %%
age_means = all_data.groupby('Title')['Age'].mean().sort_values()
age_means
# Out:
# Title
# Child     5.482642
# Ms       21.937042
# Mr       32.811056
# Mrs      36.833333
# Name: Age, dtype: float64

# %%
all_data.loc[(all_data['Age'].isnull()) & (all_data['Title']=='Child'), 'Age'] = round(age_means['Child'], 2)
all_data.loc[(all_data['Age'].isnull()) & (all_data['Title']=='Ms'), 'Age'] = round(age_means['Ms'], 2)
all_data.loc[(all_data['Age'].isnull()) & (all_data['Title']=='Mr'), 'Age'] = round(age_means['Mr'], 2)
all_data.loc[(all_data['Age'].isnull()) & (all_data['Title']=='Mrs'), 'Age'] = round(age_means['Mrs'], 2)
pd.concat([all_data['Name'], all_data['Age'], all_data['Title']], axis=1).head(7)
# Out:
#                                                 Name    Age Title
# 0                            Braund, Mr. Owen Harris  22.00    Mr
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.00   Mrs
# 2                             Heikkinen, Miss. Laina  26.00    Ms
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.00   Mrs
# 4                           Allen, Mr. William Henry  35.00    Mr
# 5                                   Moran, Mr. James  32.81    Mr
# 6                            McCarthy, Mr. Timothy J  54.00    Mr

# %%
# Split the data back to train and test
# train = all_data[:891]
# test = all_data[891:]

# %% [markdown]
# ### II. Correlation

# %%
# train.columns

# %%
survivors = train['Survived']
all_data.drop(['PassengerId', 'Name', 'Ticket', 'Cabin', 'Title'], axis=1, inplace=True)

# %% [markdown]
# <b>Categorical Data</b>

# %%
pd.crosstab([all_data['Pclass']], all_data['Survived']).style.background_gradient(cmap='YlGnBu')
# Out:
# <style  type="text/css" >
#     #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow0_col0 {
#             background-color:  #ffffd9;
#         }    #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow0_col1 {
#             background-color:  #081d58;
#         }    #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow1_col0 {
#             background-color:  #f7fcc7;
#         }    #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow1_col1 {
#             background-color:  #ffffd9;
#         }    #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow2_col0 {
#             background-color:  #081d58;
#         }    #T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow2_col1 {
#             background-color:  #1e85ba;
#         }</style>
# <table id="T_42dfd400_3e58_11e9_a66e_60f677ac13fd" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdlevel0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow0_col0" class="data row0 col0" >80</td>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow0_col1" class="data row0 col1" >136</td>
#     </tr>    <tr>
#         <th id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdlevel0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow1_col0" class="data row1 col0" >97</td>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow1_col1" class="data row1 col1" >87</td>
#     </tr>    <tr>
#         <th id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdlevel0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow2_col0" class="data row2 col0" >372</td>
#         <td id="T_42dfd400_3e58_11e9_a66e_60f677ac13fdrow2_col1" class="data row2 col1" >119</td>
#     </tr></tbody>
# </table>

# %%
pd.crosstab([all_data['Sex']], all_data['Survived']).style.background_gradient(cmap='YlGnBu')
# Out:
# <style  type="text/css" >
#     #T_42e79c30_3e58_11e9_919d_60f677ac13fdrow0_col0 {
#             background-color:  #ffffd9;
#         }    #T_42e79c30_3e58_11e9_919d_60f677ac13fdrow0_col1 {
#             background-color:  #081d58;
#         }    #T_42e79c30_3e58_11e9_919d_60f677ac13fdrow1_col0 {
#             background-color:  #081d58;
#         }    #T_42e79c30_3e58_11e9_919d_60f677ac13fdrow1_col1 {
#             background-color:  #ffffd9;
#         }</style>
# <table id="T_42e79c30_3e58_11e9_919d_60f677ac13fd" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0.0</th>
#         <th class="col_heading level0 col1" >1.0</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_42e79c30_3e58_11e9_919d_60f677ac13fdlevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_42e79c30_3e58_11e9_919d_60f677ac13fdrow0_col0" class="data row0 col0" >81</td>
#         <td id="T_42e79c30_3e58_11e9_919d_60f677ac13fdrow0_col1" class="data row0 col1" >233</td>
#     </tr>    <tr>
#         <th id="T_42e79c30_3e58_11e9_919d_60f677ac13fdlevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_42e79c30_3e58_11e9_919d_60f677ac13fdrow1_col0" class="data row1 col0" >468</td>
#         <td id="T_42e79c30_3e58_11e9_919d_60f677ac13fdrow1_col1" class="data row1 col1" >109</td>
#     </tr></tbody>
# </table>

# %%
train['Age'].hist(bins=50, figsize=(8,5))

# %%
all_data['Age_Group'] = 0
all_data.loc[(all_data['Age'] > 10) & (all_data['Age'] <= 20), 'Age_Group'] = 1
all_data.loc[(all_data['Age'] > 20) & (all_data['Age'] <= 30), 'Age_Group'] = 2
all_data.loc[(all_data['Age'] > 30) & (all_data['Age'] <= 40), 'Age_Group'] = 3
all_data.loc[(all_data['Age'] > 40) & (all_data['Age'] <= 50), 'Age_Group'] = 4
all_data.loc[(all_data['Age'] > 50) & (all_data['Age'] <= 60), 'Age_Group'] = 5
all_data.loc[(all_data['Age'] > 60), 'Age_Group'] = 6
# all_data.drop(['Age'], axis=1, inplace=True)
pd.crosstab([all_data['Age_Group']], [all_data['Pclass'], all_data['Survived']]).style.background_gradient(cmap='YlGnBu')
# Out:
# <style  type="text/css" >
#     #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col0 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col1 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col2 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col3 {
#             background-color:  #2094c0;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col4 {
#             background-color:  #dff2b2;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col5 {
#             background-color:  #65c3bf;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col0 {
#             background-color:  #f5fbc2;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col1 {
#             background-color:  #bbe4b5;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col2 {
#             background-color:  #c6e9b4;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col3 {
#             background-color:  #a7dcb7;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col4 {
#             background-color:  #6bc6be;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col5 {
#             background-color:  #6fc7bd;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col0 {
#             background-color:  #83cebb;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col1 {
#             background-color:  #299dc1;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col2 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col3 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col4 {
#             background-color:  #24449c;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col5 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col0 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col1 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col2 {
#             background-color:  #253896;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col3 {
#             background-color:  #2258a5;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col4 {
#             background-color:  #081d58;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col5 {
#             background-color:  #39adc3;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col0 {
#             background-color:  #31a5c2;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col1 {
#             background-color:  #75c9bd;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col2 {
#             background-color:  #c6e9b4;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col3 {
#             background-color:  #90d4b9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col4 {
#             background-color:  #dcf1b2;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow4_col5 {
#             background-color:  #f9fdcc;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col0 {
#             background-color:  #97d6b9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col1 {
#             background-color:  #bbe4b5;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col2 {
#             background-color:  #b7e3b6;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col3 {
#             background-color:  #fafdce;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col4 {
#             background-color:  #feffd8;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow5_col5 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col0 {
#             background-color:  #83cebb;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col1 {
#             background-color:  #fcfed3;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col2 {
#             background-color:  #f7fcc7;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col3 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col4 {
#             background-color:  #ffffd9;
#         }    #T_43254170_3e58_11e9_a010_60f677ac13fdrow6_col5 {
#             background-color:  #fcfed3;
#         }</style>
# <table id="T_43254170_3e58_11e9_a010_60f677ac13fd" >
# <thead>    <tr>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" colspan=2>1</th>
#         <th class="col_heading level0 col2" colspan=2>2</th>
#         <th class="col_heading level0 col4" colspan=2>3</th>
#     </tr>    <tr>
#         <th class="index_name level1" >Survived</th>
#         <th class="col_heading level1 col0" >0.0</th>
#         <th class="col_heading level1 col1" >1.0</th>
#         <th class="col_heading level1 col2" >0.0</th>
#         <th class="col_heading level1 col3" >1.0</th>
#         <th class="col_heading level1 col4" >0.0</th>
#         <th class="col_heading level1 col5" >1.0</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Age_Group</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_43254170_3e58_11e9_a010_60f677ac13fdlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col0" class="data row0 col0" >1</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col1" class="data row0 col1" >2</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col2" class="data row0 col2" >0</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col3" class="data row0 col3" >17</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col4" class="data row0 col4" >27</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow0_col5" class="data row0 col5" >21</td>
#     </tr>    <tr>
#         <th id="T_43254170_3e58_11e9_a010_60f677ac13fdlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col0" class="data row1 col0" >3</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col1" class="data row1 col1" >15</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col2" class="data row1 col2" >9</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col3" class="data row1 col3" >9</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col4" class="data row1 col4" >59</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow1_col5" class="data row1 col5" >20</td>
#     </tr>    <tr>
#         <th id="T_43254170_3e58_11e9_a010_60f677ac13fdlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col0" class="data row2 col0" >11</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col1" class="data row2 col1" >30</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col2" class="data row2 col2" >36</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col3" class="data row2 col3" >27</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col4" class="data row2 col4" >113</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow2_col5" class="data row2 col5" >49</td>
#     </tr>    <tr>
#         <th id="T_43254170_3e58_11e9_a010_60f677ac13fdlevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col0" class="data row3 col0" >28</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col1" class="data row3 col1" >50</td>
#         <td id="T_43254170_3e58_11e9_a010_60f677ac13fdrow3_col2" class="data row3 col2" >31</td>
#         <td id="T_43254170_

# %%
sns.factorplot('Age_Group', 'Survived', data=all_data, col='Pclass')

# %%
sns.heatmap(all_data.corr(), annot=True, cmap='RdYlGn', annot_kws={'size':20})
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.show()

# %%
all_data.columns
# Out:
# Index([u'Age', u'Embarked', u'Fare', u'Parch', u'Pclass', u'Sex', u'SibSp',
#        u'Survived', u'Age_Group'],
#       dtype='object')

# %%
train = all_data[:891]
test = all_data[891:]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
t_train, t_test = train_test_split(train, test_size=0.3, stratify=train['Survived'])
