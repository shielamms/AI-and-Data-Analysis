# %%
import pandas as pd
import numpy as np

# %%
all_data = pd.read_csv('iris\iris.csv')

# %%
all_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
all_data['species'] = label_encoder.fit_transform(all_data['species'])
all_data['species'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

all_labels = all_data['species'].copy()
all_features = all_data.drop(['species'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(all_features, all_labels, test_size=0.3, random_state=0)

# %%
X_train.shape, y_train.shape
# Out:
# ((105, 4), (105,))

# %%
X_test.shape, y_test.shape
# Out:
# ((45, 4), (45,))

# %%
# Reshape features for NN
X_train = X_train.T
X_test = X_test.T

# %%
# Reshape labels for NN
y_train = (pd.DataFrame(y_train)).T
y_test = (pd.DataFrame(y_test)).T

# %%
# Get the node sizes for NN
n_x = X_train.shape[0]
n_h = 6
n_y = y_train.shape[0]

# %% [markdown]
# ### Initialize the parameters

# %%
np.random.seed(2)

W1 = np.random.randn(n_h, n_x) * 0.01
b1 = np.random.randn(n_h, 1) * 0.01
W2 = np.random.randn(n_y, n_h) * 0.01
b2 = np.random.randn(n_y, 1) * 0.01

# %%
def tanh(Z):
    return np.tanh(Z)

# %%
def softmax(Z):
    expA = np.exp(Z)
    return expA / expA.sum(axis=1, keepdims=True)

# %%
def derivative_tanh(Z, A1):
    return (1 - np.power(A1, 2))

# %% [markdown]
# ### Forward-Propagate

# %%
def forward_propagate(X, W1, b1, W2, b2):
    Z1 = np.dot(W1, X) + b1
    A1 = tanh(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = softmax(Z2)
    
    cache = {
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'A2': A2
    }
    
    return cache

# %%
forward_try_result = forward_propagate(X_train, W1, b1, W2, b2)
forward_try_result['A2'].shape
# Out:
# (1, 105)

# %% [markdown]
# ### Cost Function

# %%
def compute_cost(A2, Y, W1, b1, W2, b2):
    m = Y.shape[1]
    
    cost = - np.sum(np.dot(Y, np.log(A2).T), axis=1) / m
    cost = cost.reshape(-1, 1)
    
    return cost

# %%
cost_try_result = compute_cost(forward_try_result['A2'], y_train, W1, b1, W2, b2)
cost_try_result.shape
# Out:
# (1, 1)

# %% [markdown]
# ### Backward-Propagate

# %%
def backward_propagagate(X, Y, forward_result, W1, b1, W2, b2):
    m = X.shape[1]
    
    A1 = forward_result['A1']
    A2 = forward_result['A2']
    Z1 = forward_result['Z1']
    
    dZ2 = A2 - Y
    dW2 = (1/m) * np.dot(dZ2, A1.T)
    db2 = (1/m) * np.sum(dZ2, axis=1).to_numpy().reshape(-1, 1)
    
    dZ1 = np.dot(W2.T, dZ2) * derivative_tanh(Z1, A1)
    dW1 = (1/m) * np.dot(dZ1, X.T)
    db1 = (1/m) * np.sum(dZ1, axis=1).reshape(-1, 1)
    
    grads = {
        'dZ2': dZ2,
        'dW2': dW2,
        'db2': db2,
        'dZ1': dZ1,
        'dW1': dW1,
        'db1': db1
    }
#     return None
    return grads

# %%
backward_try_result = backward_propagagate(X_train, y_train, forward_try_result, W1, b1, W2, b2)
backward_try_result['db1'].shape
# Out:
# (6, 1)

# %%
def update_params(W1, b1, W2, b2, backward_result, learning_rate=0.001):
    
    dW1 = backward_result['dW1']
    db1 = backward_result['db1']
    dW2 = backward_result['dW2']
    db2 = backward_result['db2']
    
    W1 = W1 - learning_rate*dW1
    b1 = b1 - learning_rate*db1
    W2 = W2 - learning_rate*dW2
    b2 = b2 - learning_rate*db2
    
    return W1, b1, W2, b2

# %%
# Train the Neural Network!
def nn_model(X, Y, W1, b1, W2, b2, num_iterations=1000):
    for i in range(0, num_iterations):
        forward_result = forward_propagate(X, W1, b1, W2, b2)
        cost = compute_cost(forward_result['A2'], Y, W1, b1, W2, b2)
        backward_result = backward_propagagate(X, Y, forward_result, W1, b1, W2, b2)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, backward_result, learning_rate=0.009)
        
        print('Cost after iteration i:', i, cost) 
        
    return W1, b1, W2, b2

# %%
W1, b1, W2, b2 = nn_model(X_train, y_train, W1, b1, W2, b2, num_iterations=1000)
# Out:
# Cost after iteration i: 0 [[4.83121748]]
# Cost after iteration i: 1 [[4.83123341]]
# Cost after iteration i: 2 [[4.83124932]]
# Cost after iteration i: 3 [[4.8312652]]
# Cost after iteration i: 4 [[4.83128107]]
# Cost after iteration i: 5 [[4.83129691]]
# Cost after iteration i: 6 [[4.83131274]]
# Cost after iteration i: 7 [[4.83132854]]
# Cost after iteration i: 8 [[4.83134433]]
# Cost after iteration i: 9 [[4.83136009]]
# Cost after iteration i: 10 [[4.83137583]]
# Cost after iteration i: 11 [[4.83139156]]
# Cost after iteration i: 12 [[4.83140726]]
# Cost after iteration i: 13 [[4.83142294]]
# Cost after iteration i: 14 [[4.83143861]]
# Cost after iteration i: 15 [[4.83145425]]
# Cost after iteration i: 16 [[4.83146987]]
# Cost after iteration i: 17 [[4.83148548]]
# Cost after iteration i: 18 [[4.83150106]]
# Cost after iteration i: 19 [[4.83151662]]
# Cost after iteration i: 20 [[4.83153217]]
# Cost after iteration i: 21 [[4.83154769]]
# Cost after iteration i: 22 [[4.8315632]]
# Cost after iteration i: 23 [[4.83157868]]
# Cost after iteration i: 24 [[4.83159415]]
# Cost after iteration i: 25 [[4.83160959]]
# Cost after iteration i: 26 [[4.83162502]]
# Cost after iteration i: 27 [[4.83164043]]
# Cost after iteration i: 28 [[4.83165582]]
# Cost after iteration i: 29 [[4.83167118]]
# Cost after iteration i: 30 [[4.83168653]]
# Cost after iteration i: 31 [[4.83170186]]
# Cost after iteration i: 32 [[4.83171717]]
# Cost after iteration i: 33 [[4.83173247]]
# Cost after iteration i: 34 [[4.83174774]]
# Cost after iteration i: 35 [[4.83176299]]
# Cost after iteration i: 36 [[4.83177823]]
# Cost after iteration i: 37 [[4.83179344]]
# Cost after iteration i: 38 [[4.83180864]]
# Cost after iteration i: 39 [[4.83182381]]
# Cost after iteration i: 40 [[4.83183897]]
# Cost after iteration i: 41 [[4.83185411]]
# Cost after iteration i: 42 [[4.83186923]]
# Cost after iteration i: 43 [[4.83188433]]
# Cost after iteration i: 44 [[4.83189942]]
# Cost after iteration i: 45 [[4.83191448]]
# Cost after iteration i: 46 [[4.83192953]]
# Cost after iteration i: 47 [[4.83194456]]
# Cost after iteration i: 48 [[4.83195956]]
# Cost after iteration i: 49 [[4.83197455]]
# Cost after iteration i: 50 [[4.83198953]]
# Cost after iteration i: 51 [[4.83200448]]
# Cost after iteration i: 52 [[4.83201941]]
# Cost after iteration i: 53 [[4.83203433]]
# Cost after iteration i: 54 [[4.83204923]]
# Cost after iteration i: 55 [[4.83206411]]
# Cost after iteration i: 56 [[4.83207897]]
# Cost after iteration i: 57 [[4.83209381]]
# Cost after iteration i: 58 [[4.83210864]]
# Cost after iteration i: 59 [[4.83212344]]
# Cost after iteration i: 60 [[4.83213823]]
# Cost after iteration i: 61 [[4.832153]]
# Cost after iteration i: 62 [[4.83216776]]
# Cost after iteration i: 63 [[4.83218249]]
# Cost after iteration i: 64 [[4.83219721]]
# Cost after iteration i: 65 [[4.83221191]]
# Cost after iteration i: 66 [[4.83222659]]
# Cost after iteration i: 67 [[4.83224125]]
# Cost after iteration i: 68 [[4.8322559]]
# Cost after iteration i: 69 [[4.83227052]]
# Cost after iteration i: 70 [[4.83228513]]
# Cost after iteration i: 71 [[4.83229973]]
# Cost after iteration i: 72 [[4.8323143]]
# Cost after iteration i: 73 [[4.83232886]]
# Cost after iteration i: 74 [[4.8323434]]
# Cost after iteration i: 75 [[4.83235792]]
# Cost after iteration i: 76 [[4.83237242]]
# Cost after iteration i: 77 [[4.83238691]]
# Cost after iteration i: 78 [[4.83240138]]
# Cost after iteration i: 79 [[4.83241583]]
# Cost after iteration i: 80 [[4.83243027]]
# Cost after iteration i: 81 [[4.83244468]]
# Cost after iteration i: 82 [[4.83245908]]
# Cost after iteration i: 83 [[4.83247347]]
# Cost after iteration i: 84 [[4.83248783]]
# Cost after iteration i: 85 [[4.83250218]]
# Cost after iteration i: 86 [[4.83251651]]
# Cost after iteration i: 87 [[4.83253083]]
# Cost after iteration i: 88 [[4.83254512]]
# Cost after iteration i: 89 [[4.8325594]]
# Cost after iteration i: 90 [[4.83257367]]
# Cost after iteration i: 91 [[4.83258791]]
# Cost after iteration i: 92 [[4.83260214]]
# Cost after iteration i: 93 [[4.83261635]]
# Cost after iteration i: 94 [[4.83263055]]
# Cost after iteration i: 95 [[4.83264473]]
# Cost after iteration i: 96 [[4.83265889]]
# Cost after iteration i: 97 [[4.83267303]]
# Cost after iteration i: 98 [[4.83268716]]
# Cost after iteration i: 99 [[4.83270127]]
# Cost after iteration i: 100 [[4.83271537]]
# Cost after iteration i: 101 [[4.83272945]]
# Cost after iteration i: 102 [[4.83274351]]
# Cost after iteration i: 103 [[4.83275755]]
# Cost after iteration i: 104 [[4.83277158]]
# Cost after iteration i: 105 [[4.83278559]]
# Cost after iteration i: 106 [[4.83279959]]
# Cost after iteration i: 107 [[4.83281357]]
# Cost after iteration i: 108 [[4.83282753]]
# Cost after iteration i: 109 [[4.83284148]]
# Cost after iteration i: 110 [[4.83285541]]
# Cost after iteration i: 111 [[4.83286932]]
# Cost after iteration i: 112 [[4.83288322]]
# Cost after iteration i: 113 [[4.8328971]]
# Cost after iteration i: 114 [[4.83291097]]
# Cost after iteration i: 115 [[4.83292482]]
# Cost after iteration i: 116 [[4.83293865]]
# Cost after iteration i: 117 [[4.83295247]]
# Cost after iteration i: 118 [[4.83296627]]
# Cost after iteration i: 119 [[4.83298005]]
# Cost after iteration i: 120 [[4.83299382]]
# Cost after iteration i: 121 [[4.83300757]]
# Cost after iteration i: 122 [[4.83302131]]
# Cost after iteration i: 123 [[4.83303503]]
# Cost after iteration i: 124 [[4.83304874]]
# Cost after iteration i: 125 [[4.83306242]]
# Cost after iteration i: 126 [[4.8330761]]
# Cost after iteration i: 127 [[4.83308976]]
# Cost after iteration i: 128 [[4.8331034]]
# Cost after iteration i: 129 [[4.83311702]]
# Cost after iteration i: 130 [[4.83313063]]
# Cost after iteration i: 131 [[4.83314423]]
# Cost after iteration i: 132 [[4.83315781]]
# Cost after iteration i: 133 [[4.83317137]]
# Cost after iteration i: 134 [[4.83318492]]
# Cost after iteration i: 135 [[4.83319845]]
# Cost after iteration i: 136 [[4.83321197]]
# Cost after iteration i: 137 [[4.83322547]]
# Cost after iteration i: 138 [[4.83323896]]
# Cost after iteration i: 139 [[4.83325243]]
# Cost after iteration i: 140 [[4.83326588]]
# Cost after iteration i: 141 [[4.83327932]]
# Cost after iteration i: 142 [[4.83329275]]
# Cost after iteration i: 143 [[4.83330616]]
# Cost after iteration i: 144 [[4.83331955]]
# Cost after iteration i: 145 [[4.83333293]]
# Cost after iteration i: 146 [[4.8333463]]
# Cost after iteration i: 147 [[4.83335964]]
# Cost after iteration i: 148 [[4.83337298]]
# Cost after iteration i: 149 [[4.8333863]]
# Cost after iteration i: 150 [[4.8333996]]
# Cost after iteration i: 151 [[4.83341289]]
# Cost after iteration i: 152 [[4.83342616]]
# Cost after iteration i: 153 [[4.83343942]]
# Cost after iteration i: 154 [[4.83345266]]
# Cost after iteration i: 155 [[4.83346589]]
# Cost after iteration i: 156 [[4.8334791]]
# Cost after iteration i: 157 [[4.8334923]]
# Cost after iteration i: 158 [[4.83350549]]
# Cost after iteration i: 159 [[4.83351866]]
# Cost after iteration i: 160 [[4.83353181]]
# Cost after iteration i: 161 [[4.83354495]]
# Cost after iteration i: 162 [[4.83355807]]
# Cost after iteration i: 163 [[4.83357118]]
# Cost after iteration i: 164 [[4.83358428]]
# Cost after iteration i: 165 [[4.83359736]]
# Cost after iteration i: 166 [[4.83361043]]
# Cost after iteration i: 167 [[4.83362348]]
# Cost after iteration i: 168 [[4.83363652]]
# Cost after iteration i: 169 [[4.83364954]]
# Cost after iteration i: 170 [[4.83366255]]
# Cost after iteration i: 171 [[4.83367554]]
# Cost after iteration i: 172 [[4.83368852]]
# Cost after iteration i: 173 [[4.83370148]]
# Cost after iteration i: 174 [[4.83371443]]
# Cost after iteration i: 175 [[4.83372737]]
# Cost after iteration i: 176 [[4.83374029]]
# Cost after iteration i: 177 [[4.8337532]]
# Cost after iteration i: 178 [[4.83376609]]
# Cost after iteration i: 179 [[4.83377897]]
# Cost after iteration i: 180 [[4.83379184]]
# Cost after iteration i: 181 [[4.83380469]]
# Cost after iteration i: 182 [[4.83381752]]
# Cost after iteration i: 183 [[4.83383034]]
# Cost after iteration i: 184 [[4.83384315]]
# Cost after iteration i: 185 [[4.83385595]]
# Cost after iteration i: 186 [[4.83386873]]
# Cost after iteration i: 187 [[4.83388149]]
# Cost after iteration i: 188 [[4.83389424]]
# Cost after iteration i: 189 [[4.83390698]]
# Cost after iteration i: 190 [[4.8339197]]
# Cost after iteration i: 191 [[4.83393241]]
# Cost after iteration i: 192 [[4.83394511]]
# Cost after iteration i: 193 [[4.83395779]]
# Cost after iteration i: 194 [[4.83397046]]
# Cost after iteration i: 195 [[4.83398312]]
# Cost after iteration i: 196 [[4.83399576]]
# Cost after iteration i: 197 [[4.83400838]]
# Cost after iteration i: 198 [[4.834021]]
# Cost after iteration i: 199 [[4.8340336]]
# Cost after iteration i: 200 [[4.83404618]]
# Cost after iteration i: 201 [[4.83405875]]
# Cost after iteration i: 202 [[4.83407131]]
# Cost after iteration i: 203 [[4.83408386]]
# Cost after iteration i: 204 [[4.83409639]]
# Cost after iteration i: 205 [[4.8341089]]
# Cost after iteration i: 206 [[4.83412141]]
# Cost after iteration i: 207 [[4.8341339]]
# Cost after iteration i: 208 [[4.83414638]]
# Cost after iteration i: 209 [[4.83415884]]
# Cost after iteration i: 210 [[4.83417129]]
# Cost after iteration i: 211 [[4.83418373]]
# Cost after iteration i: 212 [[4.83419615]]
# Cost after iteration i: 213 [[4.83420856]]
# Cost after iteration i: 214 [[4.83422096]]
# Cost after iteration i: 215 [[4.83423334]]
# Cost after iteration i: 216 [[4.83424571]]
# Cost after iteration i: 217 [[4.83425807]]
# Cost after iteration i: 218 [[4.83427041]]
# Cost after iteration i: 219 [[4.83428274]]
# Cost after iteration i: 220 [[4.83429506]]
# Cost after iteration i: 221 [[4.83430736]]
# Cost after iteration i: 222 [[4.83431965]]
# Cost after iteration i: 223 [[4.83433193]]
# Cost after iteration i: 224 [[4.8343442]]
# Cost after iteration i: 225 [[4.83435645]]
# Cost after iteration i: 226 [[4.83436869]]
# Cost after iteration i: 227 [[4.83438091]]
# Cost after iteration i: 228 [[4.83439312]]
# Cost after iteration i: 229 [[4.83440532]]
# Cost after iteration i: 230 [[4.83441751]]
# Cost after iteration i: 231 [[4.83442968]]
# Cost after iteration i: 232 [[4.83444184]]
# Cost after iteration i: 233 [[4.83445399]]
# Cost after iteration i: 234 [[4.83446613]]
# Cost after iteration i: 235 [[4.83447825]]
# Cost after iteration i: 236 [[4.83449036]]
# Cost after iteration i: 237 [[4.83450246]]
# Cost after iteration i: 238 [[4.83451454]]
# Cost after iteration i: 239 [[4.83452661]]
# Cost after iteration i: 240 [[4.83453867]]
# Cost after iteration i: 241 [[4.83455071]]
# Cost after iteration i: 242 [[4.83456275]]
# Cost after iteration i: 243 [[4.83457477]]
# Cost after iteration i: 244 [[4.83458678]]
# Cost after iteration i: 245 [[4.83459877]]
# Cost after iteration i: 246 [[4.83461075]]
# Cost after iteration i: 247 [[4.83462272]]
# Cost after iteration i: 248 [[4.83463468]]
# Cost after iteration i: 249 [[4.83464663]]
# Cost after iteration i: 250 [[4.83465856]]
# Cost after iteration i: 251 [[4.83467048]]
# Cost after iteration i: 252 [[4.83468239]]
# Cost after iteration i: 253 [[4.83469428]]
# Cost after iteration i: 254 [[4.83470616]]
# Cost after iteration i: 255 [[4.83471803]]
# Cost after iteration i: 256 [[4.83472989]]
# Cost after iteration i: 257 [[4.83474174]]
# Cost after iteration i: 258 [[4.83475357]]
# Cost after iteration i: 259 [[4.83476539]]
# Cost after iteration i: 260 [[4.8347772]]
# Cost after iteration i: 261 [[4.834789]]
# Cost after iteration i: 262 [[4.83480078]]
# Cost after iteration i: 263 [[4.83481255]]
# Cost after iteration i: 264 [[4.83482431]]
# Cost after iteration i: 265 [[4.83483606]]
# Cost after iteration i: 266 [[4.8348478]]
# Cost after iteration i: 267 [[4.83485952]]
# Cost after iteration i: 268 [[4.83487123]]
# Cost after iteration i: 269 [[4.83488293]]
# Cost after iteration i: 270 [[4.83489462]]
# Cost after iteration i: 271 [[4.83490629]]
# Cost after iteration i: 272 [[4.83491796]]
# Cost after iteration i: 273 [[4.83492961]]
# Cost after iteration i: 274 [[4.83494125]]
# Cost after iteration i: 275 [[4.83495288]]
# Cost after iteration i: 276 [[4.83496449]]
# Cost after iteration i: 277 [[4.83497609]]
# Cost after iteration i: 278 [[4.83498769]]
# Cost after iteration i: 279 [[4.83499927]]
# Cost after iteration i: 280 [[4.83501083]]
# Cost after iteration i: 281 [[4.83502239]]
# Cost after iteration i: 282 [[4.83503393]]
# Cost after iteration i: 283 [[4.83504547]]
# Cost after iteration i: 284 [[4.83505699]]
# Cost after iteration i: 285 [[4.8350685]]
# Cost after iteration i: 286 [[4.83508]]
# Cost after iteration i: 287 [[4.83509148]]
# Cost after iteration i: 288 [[4.83510295]]
# Cost after iteration i: 289 [[4.83511442]]
# Cost after iteration i: 290 [[4.83512587]]
# Cost after iteration i: 291 [[4.83513731]]
# Cost after iteration i: 292 [[4.83514874]]
# Cost after iteration i: 293 [[4.83516015]]
# Cost after iteration i: 294 [[4.83517156]]
# Cost after iteration i: 295 [[4.83518295]]
# Cost after iteration i: 296 [[4.83519433]]
# Cost after iteration i: 297 [[4.8352057]]
# Cost after iteration i: 298 [[4.83521706]]
# Cost after iteration i: 299 [[4.83522841]]
# Cost after iteration i: 300 [[4.83523974]]
# Cost after iteration i: 301 [[4.83525107]]
# Cost after iteration i: 302 [[4.83526238]]
# Cost after iteration i: 303 [[4.83527368]]
# Cost after iteration i: 304 [[4.83528497]]
# Cost after iteration i: 305 [[4.83529625]]
# Cost after iteration i: 306 [[4.83530752]]
# Cost after iteration i: 307 [[4.83531877]]
# Cost after iteration i: 308 [[4.83533002]]
# Cost after iteration i: 309 [[4.83534125]]
# Cost after iteration i: 310 [[4.83535247]]
# Cost after iteration i: 311 [[4.83536368]]
# Cost after iteration i: 312 [[4.83537488]]
# Cost after iteration i: 313 [[4.83538607]]
# Cost after iteration i: 314 [[4.83539725]]
# Cost after iteration i: 315 [[4.83540842]]
# Cost after iteration i: 316 [[4.83541957]]
# Cost after iteration i: 317 [[4.83543072]]
# Cost after iteration i: 318 [[4.83544185]]
# Cost after iteration i: 319 [[4.83545297]]
# Cost after iteration i: 320 [[4.83546408]]
# Cost after iteration i: 321 [[4.83547518]]
# Cost after iteration i: 322 [[4.83548627]]
# Cost after iteration i: 323 [[4.83549735]]
# Cost after iteration i: 324 [[4.83550842]]
# Cost after iteration i: 325 [[4.83551948]]
# Cost after iteration i: 326 [[4.83553052]]
# Cost after iteration i: 327 [[4.83554156]]
# Cost after iteration i: 328 [[4.83555258]]
# Cost after iteration i: 329 [[4.83556359]]
# Cost after iteration i: 330 [[4.83557459]]
# Cost after iteration i: 331 [[4.83558558]]
# Cost after iteration i: 332 [[4.83559656]]
# Cost after iteration i: 333 [[4.83560753]]
# Cost after iteration i: 334 [[4.83561849]]
# Cost after iteration i: 335 [[4.83562944]]
# Cost after iteration i: 336 [[4.83564038]]
# Cost after iteration i: 337 [[4.8356513]]
# Cost after iteration i: 338 [[4.83566222]]
# Cost after iteration i: 339 [[4.83567312]]
# Cost after iteration i: 340 [[4.83568402]]
# Cost after iteration i: 341 [[4.8356949]]
# Cost after iteration i: 342 [[4.83570577]]
# Cost after iteration i: 343 [[4.83571664]]
# Cost after iteration i: 344 [[4.83572749]]
# Cost after iteration i: 345 [[4.83573833]]
# Cost after iteration i: 346 [[4.83574916]]
# Cost after iteration i: 347 [[4.83575998]]
# Cost after iteration i: 348 [[4.83577079]]
# Cost after iteration i: 349 [[4.83578159]]
# Cost after iteration i: 350 [[4.83579238]]
# Cost after iteration i: 351 [[4.83580316]]
# Cost after iteration i: 352 [[4.83581392]]
# Cost after iteration i: 353 [[4.83582468]]
# Cost after iteration i: 354 [[4.83583543]]
# Cost after iteration i: 355 [[4.83584616]]
# Cost after iteration i: 356 [[4.83585689]]
# Cost after iteration i: 357 [[4.83586761]]
# Cost after iteration i: 358 [[4.83587831]]
# Cost after iteration i: 359 [[4.83588901]]
# Cost after iteration i: 360 [[4.83589969]]
# Cost after iteration i: 361 [[4.83591036]]
# Cost after iteration i: 362 [[4.83592103]]
# Cost after iteration i: 363 [[4.83593168]]
# Cost after iteration i: 364 [[4.83594233]]
# Cost after iteration i: 365 [[4.83595296]]
# Cost after iteration i: 366 [[4.83596358]]
# Cost after iteration i: 367 [[4.8359742]]
# Cost after iteration i: 368 [[4.8359848]]
# Cost after iteration i: 369 [[4.83599539]]
# Cost after iteration i: 370 [[4.83600597]]
# Cost after iteration i: 371 [[4.83601654]]
# Cost after iteration i: 372 [[4.83602711]]
# Cost after iteration i: 373 [[4.83603766]]
# Cost after iteration i: 374 [[4.8360482]]
# Cost after iteration i: 375 [[4.83605873]]
# Cost after iteration i: 376 [[4.83606925]]
# Cost after iteration i: 377 [[4.83607977]]
# Cost after iteration i: 378 [[4.83609027]]
# Cost after iteration i: 379 [[4.83610076]]
# Cost after iteration i: 380 [[4.83611124]]
# Cost after iteration i: 381 [[4.83612171]]
# Cost after iteration i: 382 [[4.83613218]]
# Cost after iteration i: 383 [[4.83614263]]
# Cost after iteration i: 384 [[4.83615307]]
# Cost after iteration i: 385 [[4.8361635]]
# Cost after iteration i: 386 [[4.83617392]]
# Cost after iteration i: 387 [[4.83618434]]
# Cost after iteration i: 388 [[4.83619474]]
# Cost after iteration i: 389 [[4.83620513]]
# Cost after iteration i: 390 [[4.83621551]]
# Cost after iteration i: 391 [[4.83622589]]
# Cost after iteration i: 392 [[4.83623625]]
# Cost after iteration i: 393 [[4.8362466]]
# Cost after iteration i: 394 [[4.83625695]]
# Cost after iteration i: 395 [[4.83626728]]
# Cost after iteration i: 396 [[4.83627761]]
# Cost after iteration i: 397 [[4.83628792]]
# Cost after iteration i: 398 [[4.83629822]]
# Cost after iteration i: 399 [[4.83630852]]
# Cost after iteration i: 400 [[4.83631881]]
# Cost after iteration i: 401 [[4.83632908]]
# Cost after iteration i: 402 [[4.83633935]]
# Cost after iteration i: 403 [[4.8363496]]
# Cost after iteration i: 404 [[4.83635985]]
# Cost after iteration i: 405 [[4.83637009]]
# Cost after iteration i: 406 [[4.83638032]]
# Cost after iteration i: 407 [[4.83639053]]
# Cost after iteration i: 408 [[4.83640074]]
# Cost after iteration i: 409 [[4.83641094]]
# Cost after iteration i: 410 [[4.83642113]]
# Cost after iteration i: 411 [[4.83643131]]
# Cost after iteration i: 412 [[4.83644148]]
# Cost after iteration i: 413 [[4.83645164]]
# Cost after iteration i: 414 [[4.8364618]]
# Cost after iteration i: 415 [[4.83647194]]
# Cost after iteration i: 416 [[4.83648207]]
# Cost after iteration i: 417 [[4.8364922]]
# Cost after iteration i: 418 [[4.83650231]]
# Cost after iteration i: 419 [[4.83651241]]
# Cost after iteration i: 420 [[4.83652251]]
# Cost after iteration i: 421 [[4.8365326]]
# Cost after iteration i: 422 [[4.83654267]]
# Cost after iteration i: 423 [[4.83655274]]
# Cost after iteration i: 424 [[4.8365628]]
# Cost after iteration i: 425 [[4.83657285]]
# Cost after iteration i: 426 [[4.83658289]]
# Cost after iteration i: 427 [[4.83659292]]
# Cost after iteration i: 428 [[4.83660294]]
# Cost after iteration i: 429 [[4.83661295]]
# Cost after iteration i: 430 [[4.83662295]]
# Cost after iteration i: 431 [[4.83663295]]
# Cost after iteration i: 432 [[4.83664293]]
# Cost after iteration i: 433 [[4.83665291]]
# Cost after iteration i: 434 [[4.83666287]]
# Cost after iteration i: 435 [[4.83667283]]
# Cost after iteration i: 436 [[4.83668278]]
# Cost after iteration i: 437 [[4.83669272]]
# Cost after iteration i: 438 [[4.83670265]]
# Cost after iteration i: 439 [[4.83671257]]
# Cost after iteration i: 440 [[4.83672248]]
# Cost after iteration i: 441 [[4.83673238]]
# Cost after iteration i: 442 [[4.83674227]]
# Cost after iteration i: 443 [[4.83675216]]
# Cost after iteration i: 444 [[4.83676203]]
# Cost after iteration i: 445 [[4.8367719]]
# Cost after iteration i: 446 [[4.83678176]]
# Cost after iteration i: 447 [[4.8367916]]
# Cost after iteration i: 448 [[4.83680144]]
# Cost after iteration i: 449 [[4.83681127]]
# Cost after iteration i: 450 [[4.8368211]]
# Cost after iteration i: 451 [[4.83683091]]
# Cost after iteration i: 452 [[4.83684071]]
# Cost after iteration i: 453 [[4.83685051]]
# Cost after iteration i: 454 [[4.83686029]]
# Cost after iteration i: 455 [[4.83687007]]
# Cost after iteration i: 456 [[4.83687984]]
# Cost after iteration i: 457 [[4.8368896]]
# Cost after iteration i: 458 [[4.83689935]]
# Cost after iteration i: 459 [[4.83690909]]
# Cost after iteration i: 460 [[4.83691882]]
# Cost after iteration i: 461 [[4.83692855]]
# Cost after iteration i: 462 [[4.83693826]]
# Cost after iteration i: 463 [[4.83694797]]
# Cost after iteration i: 464 [[4.83695767]]
# Cost after iteration i: 465 [[4.83696736]]
# Cost after iteration i: 466 [[4.83697704]]
# Cost after iteration i: 467 [[4.83698671]]
# Cost after iteration i: 468 [[4.83699637]]
# Cost after iteration i: 469 [[4.83700603]]
# Cost after iteration i: 470 [[4.83701567]]
# Cost after iteration i: 471 [[4.83702531]]
# Cost after iteration i: 472 [[4.83703494]]
# Cost after iteration i: 473 [[4.83704456]]
# Cost after iteration i: 474 [[4.83705417]]
# Cost after iteration i: 475 [[4.83706378]]
# Cost after iteration i: 476 [[4.83707337]]
# Cost after iteration i: 477 [[4.83708296]]
# Cost after iteration i: 478 [[4.83709253]]
# Cost after iteration i: 479 [[4.8371021]]
# Cost after iteration i: 480 [[4.83711166]]
# Cost after iteration i: 481 [[4.83712121]]
# Cost after iteration i: 482 [[4.83713076]]
# Cost after iteration i: 483 [[4.83714029]]
# Cost after iteration i: 484 [[4.83714982]]
# Cost after iteration i: 485 [[4.83715934]]
# Cost after iteration i: 486 [[4.83716885]]
# Cost after iteration i: 487 [[4.83717835]]
# Cost after iteration i: 488 [[4.83718784]]
# Cost after iteration i: 489 [[4.83719732]]
# Cost after iteration i: 490 [[4.8372068]]
# Cost after iteration i: 491 [[4.83721627]]
# Cost after iteration i: 492 [[4.83722572]]
# Cost after iteration i: 493 [[4.83723518]]
# Cost after iteration i: 494 [[4.83724462]]
# Cost after iteration i: 495 [[4.83725405]]
# Cost after iteration i: 496 [[4.83726348]]
# Cost after iteration i: 497 [[4.83727289]]
# Cost after iteration i: 498 [[4.8372823]]
# Cost after iteration i: 499 [[4.8372917]]
# Cost after iteration i: 500 [[4.8373011]]
# Cost after iteration i: 501 [[4.83731048]]
# Cost after iteration i: 502 [[4.83731986]]
# Cost after iteration i: 503 [[4.83732923]]
# Cost after iteration i: 504 [[4.83733859]]
# Cost after iteration i: 505 [[4.83734794]]
# Cost after iteration i: 506 [[4.83735728]]
# Cost after iteration i: 507 [[4.83736661]]
# Cost after iteration i: 508 [[4.83737594]]
# Cost after iteration i: 509 [[4.83738526]]
# Cost after iteration i: 510 [[4.83739457]]
# Cost after iteration i: 511 [[4.83740387]]
# Cost after iteration i: 512 [[4.83741317]]
# Cost after iteration i: 513 [[4.83742245]]
# Cost after iteration i: 514 [[4.83743173]]
# Cost after iteration i: 515 [[4.837441]]
# Cost after iteration i: 516 [[4.83745026]]
# Cost after iteration i: 517 [[4.83745952]]
# Cost after iteration i: 518 [[4.83746876]]
# Cost after iteration i: 519 [[4.837478]]
# Cost after iteration i: 520 [[4.83748723]]
# Cost after iteration i: 521 [[4.83749645]]
# Cost after iteration i: 522 [[4.83750567]]
# Cost after iteration i: 523 [[4.83751487]]
# Cost after iteration i: 524 [[4.83752407]]
# Cost after iteration i: 525 [[4.83753326]]
# Cost after iteration i: 526 [[4.83754244]]
# Cost after iteration i: 527 [[4.83755162]]
# Cost after iteration i: 528 [[4.83756078]]
# Cost after iteration i: 529 [[4.83756994]]
# Cost after iteration i: 530 [[4.83757909]]
# Cost after iteration i: 531 [[4.83758824]]
# Cost after iteration i: 532 [[4.83759737]]
# Cost after iteration i: 533 [[4.8376065]]
# Cost after iteration i: 534 [[4.83761562]]
# Cost after iteration i: 535 [[4.83762473]]
# Cost after iteration i: 536 [[4.83763383]]
# Cost after iteration i: 537 [[4.83764293]]
# Cost after iteration i: 538 [[4.83765201]]
# Cost after iteration i: 539 [[4.83766109]]
# Cost after iteration i: 540 [[4.83767017]]
# Cost after iteration i: 541 [[4.83767923]]
# Cost after iteration i: 542 [[4.83768829]]
# Cost after iteration i: 543 [[4.83769733]]
# Cost after iteration i: 544 [[4.83770638]]
# Cost after iteration i: 545 [[4.83771541]]
# Cost after iteration i: 546 [[4.83772443]]
# Cost after iteration i: 547 [[4.83773345]]
# Cost after iteration i: 548 [[4.83774246]]
# Cost after iteration i: 549 [[4.83775147]]
# Cost after iteration i: 550 [[4.83776046]]
# Cost after iteration i: 551 [[4.83776945]]
# Cost after iteration i: 552 [[4.83777843]]
# Cost after iteration i: 553 [[4.8377874]]
# Cost after iteration i: 554 [[4.83779636]]
# Cost after iteration i: 555 [[4.83780532]]
# Cost after iteration i: 556 [[4.83781427]]
# Cost after iteration i: 557 [[4.83782321]]
# Cost after iteration i: 558 [[4.83783214]]
# Cost after iteration i: 559 [[4.83784107]]
# Cost after iteration i: 560 [[4.83784999]]
# Cost after iteration i: 561 [[4.8378589]]
# Cost after iteration i: 562 [[4.8378678]]
# Cost after iteration i: 563 [[4.8378767]]
# Cost after iteration i: 564 [[4.83788559]]
# Cost after iteration i: 565 [[4.83789447]]
# Cost after iteration i: 566 [[4.83790334]]
# Cost after iteration i: 567 [[4.83791221]]
# Cost after iteration i: 568 [[4.83792107]]
# Cost after iteration i: 569 [[4.83792992]]
# Cost after iteration i: 570 [[4.83793876]]
# Cost after iteration i: 571 [[4.8379476]]
# Cost after iteration i: 572 [[4.83795643]]
# Cost after iteration i: 573 [[4.83796525]]
# Cost after iteration i: 574 [[4.83797406]]
# Cost after iteration i: 575 [[4.83798287]]
# Cost after iteration i: 576 [[4.83799167]]
# Cost after iteration i: 577 [[4.83800046]]
# Cost after iteration i: 578 [[4.83800925]]
# Cost after iteration i: 579 [[4.83801802]]
# Cost after iteration i: 580 [[4.83802679]]
# Cost after iteration i: 581 [[4.83803556]]
# Cost after iteration i: 582 [[4.83804431]]
# Cost after iteration i: 583 [[4.83805306]]
# Cost after iteration i: 584 [[4.8380618]]
# Cost after iteration i: 585 [[4.83807053]]
# Cost after iteration i: 586 [[4.83807926]]
# Cost after iteration i: 587 [[4.83808798]]
# Cost after iteration i: 588 [[4.83809669]]
# Cost after iteration i: 589 [[4.83810539]]
# Cost after iteration i: 590 [[4.83811409]]
# Cost after iteration i: 591 [[4.83812278]]
# Cost after iteration i: 592 [[4.83813146]]
# Cost after iteration i: 593 [[4.83814014]]
# Cost after iteration i: 594 [[4.83814881]]
# Cost after iteration i: 595 [[4.83815747]]
# Cost after iteration i: 596 [[4.83816612]]
# Cost after iteration i: 597 [[4.83817477]]
# Cost after iteration i: 598 [[4.83818341]]
# Cost after iteration i: 599 [[4.83819204]]
# Cost after iteration i: 600 [[4.83820067]]
# Cost after iteration i: 601 [[4.83820928]]
# Cost after iteration i: 602 [[4.8382179]]
# Cost after iteration i: 603 [[4.8382265]]
# Cost after iteration i: 604 [[4.8382351]]
# Cost after iteration i: 605 [[4.83824369]]
# Cost after iteration i: 606 [[4.83825227]]
# Cost after iteration i: 607 [[4.83826084]]
# Cost after iteration i: 608 [[4.83826941]]
# Cost after iteration i: 609 [[4.83827797]]
# Cost after iteration i: 610 [[4.83828653]]
# Cost after iteration i: 611 [[4.83829508]]
# Cost after iteration i: 612 [[4.83830362]]
# Cost after iteration i: 613 [[4.83831215]]
# Cost after iteration i: 614 [[4.83832068]]
# Cost after iteration i: 615 [[4.8383292]]
# Cost after iteration i: 616 [[4.83833771]]
# Cost after iteration i: 617 [[4.83834621]]
# Cost after iteration i: 618 [[4.83835471]]
# Cost after iteration i: 619 [[4.8383632]]
# Cost after iteration i: 620 [[4.83837169]]
# Cost after iteration i: 621 [[4.83838017]]
# Cost after iteration i: 622 [[4.83838864]]
# Cost after iteration i: 623 [[4.8383971]]
# Cost after iteration i: 624 [[4.83840556]]
# Cost after iteration i: 625 [[4.83841401]]
# Cost after iteration i: 626 [[4.83842245]]
# Cost after iteration i: 627 [[4.83843089]]
# Cost after iteration i: 628 [[4.83843932]]
# Cost after iteration i: 629 [[4.83844774]]
# Cost after iteration i: 630 [[4.83845616]]
# Cost after iteration i: 631 [[4.83846456]]
# Cost after iteration i: 632 [[4.83847297]]
# Cost after iteration i: 633 [[4.83848136]]
# Cost after iteration i: 634 [[4.83848975]]
# Cost after iteration i: 635 [[4.83849813]]
# Cost after iteration i: 636 [[4.83850651]]
# Cost after iteration i: 637 [[4.83851488]]
# Cost after iteration i: 638 [[4.83852324]]
# Cost after iteration i: 639 [[4.83853159]]
# Cost after iteration i: 640 [[4.83853994]]
# Cost after iteration i: 641 [[4.83854828]]
# Cost after iteration i: 642 [[4.83855662]]
# Cost after iteration i: 643 [[4.83856494]]
# Cost after iteration i: 644 [[4.83857326]]
# Cost after iteration i: 645 [[4.83858158]]
# Cost after iteration i: 646 [[4.83858989]]
# Cost after iteration i: 647 [[4.83859819]]
# Cost after iteration i: 648 [[4.83860648]]
# Cost after iteration i: 649 [[4.83861477]]
# Cost after iteration i: 650 [[4.83862305]]
# Cost after iteration i: 651 [[4.83863133]]
# Cost after iteration i: 652 [[4.83863959]]
# Cost after iteration i: 653 [[4.83864785]]
# Cost after iteration i: 654 [[4.83865611]]
# Cost after iteration i: 655 [[4.83866436]]
# Cost after iteration i: 656 [[4.8386726]]
# Cost after iteration i: 657 [[4.83868083]]
# Cost after iteration i: 658 [[4.83868906]]
# Cost after iteration i: 659 [[4.83869728]]
# Cost after iteration i: 660 [[4.8387055]]
# Cost after iteration i: 661 [[4.83871371]]
# Cost after iteration i: 662 [[4.83872191]]
# Cost after iteration i: 663 [[4.8387301]]
# Cost after iteration i: 664 [[4.83873829]]
# Cost after iteration i: 665 [[4.83874647]]
# Cost after iteration i: 666 [[4.83875465]]
# Cost after iteration i: 667 [[4.83876282]]
# Cost after iteration i: 668 [[4.83877098]]
# Cost after iteration i: 669 [[4.83877914]]
# Cost after iteration i: 670 [[4.83878729]]
# Cost after iteration i: 671 [[4.83879543]]
# Cost after iteration i: 672 [[4.83880357]]
# Cost after iteration i: 673 [[4.8388117]]
# Cost after iteration i: 674 [[4.83881982]]
# Cost after iteration i: 675 [[4.83882794]]
# Cost after iteration i: 676 [[4.83883605]]
# Cost after iteration i: 677 [[4.83884416]]
# Cost after iteration i: 678 [[4.83885226]]
# Cost after iteration i: 679 [[4.83886035]]
# Cost after iteration i: 680 [[4.83886843]]
# Cost after iteration i: 681 [[4.83887651]]
# Cost after iteration i: 682 [[4.83888459]]
# Cost after iteration i: 683 [[4.83889265]]
# Cost after iteration i: 684 [[4.83890071]]
# Cost after iteration i: 685 [[4.83890877]]
# Cost after iteration i: 686 [[4.83891681]]
# Cost after iteration i: 687 [[4.83892486]]
# Cost after iteration i: 688 [[4.83893289]]
# Cost after iteration i: 689 [[4.83894092]]
# Cost after iteration i: 690 [[4.83894894]]
# Cost after iteration i: 691 [[4.83895696]]
# Cost after iteration i: 692 [[4.83896497]]
# Cost after iteration i: 693 [[4.83897297]]
# Cost after iteration i: 694 [[4.83898097]]
# Cost after iteration i: 695 [[4.83898896]]
# Cost after iteration i: 696 [[4.83899694]]
# Cost after iteration i: 697 [[4.83900492]]
# Cost after iteration i: 698 [[4.83901289]]
# Cost after iteration i: 699 [[4.83902086]]
# Cost after iteration i: 700 [[4.83902882]]
# Cost after iteration i: 701 [[4.83903677]]
# Cost after iteration i: 702 [[4.83904472]]
# Cost after iteration i: 703 [[4.83905266]]
# Cost after iteration i: 704 [[4.8390606]]
# Cost after iteration i: 705 [[4.83906853]]
# Cost after iteration i: 706 [[4.83907645]]
# Cost after iteration i: 707 [[4.83908437]]
# Cost after iteration i: 708 [[4.83909228]]
# Cost after iteration i: 709 [[4.83910018]]
# Cost after iteration i: 710 [[4.83910808]]
# Cost after iteration i: 711 [[4.83911597]]
# Cost after iteration i: 712 [[4.83912386]]
# Cost after iteration i: 713 [[4.83913174]]
# Cost after iteration i: 714 [[4.83913961]]
# Cost after iteration i: 715 [[4.83914748]]
# Cost after iteration i: 716 [[4.83915534]]
# Cost after iteration i: 717 [[4.83916319]]
# Cost after iteration i: 718 [[4.83917104]]
# Cost after iteration i: 719 [[4.83917889]]
# Cost after iteration i: 720 [[4.83918672]]
# Cost after iteration i: 721 [[4.83919456]]
# Cost after iteration i: 722 [[4.83920238]]
# Cost after iteration i: 723 [[4.8392102]]
# Cost after iteration i: 724 [[4.83921801]]
# Cost after iteration i: 725 [[4.83922582]]
# Cost after iteration i: 726 [[4.83923362]]
# Cost after iteration i: 727 [[4.83924142]]
# Cost after iteration i: 728 [[4.83924921]]
# Cost after iteration i: 729 [[4.83925699]]
# Cost after iteration i: 730 [[4.83926477]]
# Cost after iteration i: 731 [[4.83927254]]
# Cost after iteration i: 732 [[4.8392803]]
# Cost after iteration i: 733 [[4.83928806]]
# Cost after iteration i: 734 [[4.83929581]]
# Cost after iteration i: 735 [[4.83930356]]
# Cost after iteration i: 736 [[4.8393113]]
# Cost after iteration i: 737 [[4.83931904]]
# Cost after iteration i: 738 [[4.83932677]]
# Cost after iteration i: 739 [[4.83933449]]
# Cost after iteration i: 740 [[4.83934221]]
# Cost after iteration i: 741 [[4.83934992]]
# Cost after iteration i: 742 [[4.83935763]]
# Cost after iteration i: 743 [[4.83936533]]
# Cost after iteration i: 744 [[4.83937302]]
# Cost after iteration i: 745 [[4.83938071]]
# Cost after iteration i: 746 [[4.83938839]]
# Cost after iteration i: 747 [[4.83939607]]
# Cost after iteration i: 748 [[4.83940374]]
# Cost after iteration i: 749 [[4.83941141]]
# Cost after iteration i: 750 [[4.83941907]]
# Cost after iteration i: 751 [[4.83942672]]
# Cost after iteration i: 752 [[4.83943437]]
# Cost after iteration i: 753 [[4.83944201]]
# Cost after iteration i: 754 [[4.83944965]]
# Cost after iteration i: 755 [[4.83945728]]
# Cost after iteration i: 756 [[4.8394649]]
# Cost after iteration i: 757 [[4.83947252]]
# Cost after iteration i: 758 [[4.83948013]]
# Cost after iteration i: 759 [[4.83948774]]
# Cost after iteration i: 760 [[4.83949534]]
# Cost after iteration i: 761 [[4.83950294]]
# Cost after iteration i: 762 [[4.83951053]]
# Cost after iteration i: 763 [[4.83951811]]
# Cost after iteration i: 764 [[4.83952569]]
# Cost after iteration i: 765 [[4.83953327]]
# Cost after iteration i: 766 [[4.83954083]]
# Cost after iteration i: 767 [[4.83954839]]
# Cost after iteration i: 768 [[4.83955595]]
# Cost after iteration i: 769 [[4.8395635]]
# Cost after iteration i: 770 [[4.83957105]]
# Cost after iteration i: 771 [[4.83957858]]
# Cost after iteration i: 772 [[4.83958612]]
# Cost after iteration i: 773 [[4.83959365]]
# Cost after iteration i: 774 [[4.83960117]]
# Cost after iteration i: 775 [[4.83960868]]
# Cost after iteration i: 776 [[4.83961619]]
# Cost after iteration i: 777 [[4.8396237]]
# Cost after iteration i: 778 [[4.8396312]]
# Cost after iteration i: 779 [[4.83963869]]
# Cost after iteration i: 780 [[4.83964618]]
# Cost after iteration i: 781 [[4.83965366]]
# Cost after iteration i: 782 [[4.83966114]]
# Cost after iteration i: 783 [[4.83966861]]
# Cost after iteration i: 784 [[4.83967608]]
# Cost after iteration i: 785 [[4.83968354]]
# Cost after iteration i: 786 [[4.83969099]]
# Cost after iteration i: 787 [[4.83969844]]
# Cost after iteration i: 788 [[4.83970589]]
# Cost after iteration i: 789 [[4.83971333]]
# Cost after iteration i: 790 [[4.83972076]]
# Cost after iteration i: 791 [[4.83972819]]
# Cost after iteration i: 792 [[4.83973561]]
# Cost after iteration i: 793 [[4.83974302]]
# Cost after iteration i: 794 [[4.83975044]]
# Cost after iteration i: 795 [[4.83975784]]
# Cost after iteration i: 796 [[4.83976524]]
# Cost after iteration i: 797 [[4.83977263]]
# Cost after iteration i: 798 [[4.83978002]]
# Cost after iteration i: 799 [[4.83978741]]
# Cost after iteration i: 800 [[4.83979478]]
# Cost after iteration i: 801 [[4.83980216]]
# Cost after iteration i: 802 [[4.83980952]]
# Cost after iteration i: 803 [[4.83981689]]
# Cost after iteration i: 804 [[4.83982424]]
# Cost after iteration i: 805 [[4.83983159]]
# Cost after iteration i: 806 [[4.83983894]]
# Cost after iteration i: 807 [[4.83984628]]
# Cost after iteration i: 808 [[4.83985361]]
# Cost after iteration i: 809 [[4.83986094]]
# Cost after iteration i: 810 [[4.83986827]]
# Cost after iteration i: 811 [[4.83987558]]
# Cost after iteration i: 812 [[4.8398829]]
# Cost after iteration i: 813 [[4.8398902]]
# Cost after iteration i: 814 [[4.83989751]]
# Cost after iteration i: 815 [[4.8399048]]
# Cost after iteration i: 816 [[4.8399121]]
# Cost after iteration i: 817 [[4.83991938]]
# Cost after iteration i: 818 [[4.83992666]]
# Cost after iteration i: 819 [[4.83993394]]
# Cost after iteration i: 820 [[4.83994121]]
# Cost after iteration i: 821 [[4.83994847]]
# Cost after iteration i: 822 [[4.83995573]]
# Cost after iteration i: 823 [[4.83996299]]
# Cost after iteration i: 824 [[4.83997024]]
# Cost after iteration i: 825 [[4.83997748]]
# Cost after iteration i: 826 [[4.83998472]]
# Cost after iteration i: 827 [[4.83999195]]
# Cost after iteration i: 828 [[4.83999918]]
# Cost after iteration i: 829 [[4.8400064]]
# Cost after iteration i: 830 [[4.84001362]]
# Cost after iteration i: 831 [[4.84002083]]
# Cost after iteration i: 832 [[4.84002804]]
# Cost after iteration i: 833 [[4.84003524]]
# Cost after iteration i: 834 [[4.84004244]]
# Cost after iteration i: 835 [[4.84004963]]
# Cost after iteration i: 836 [[4.84005682]]
# Cost after iteration i: 837 [[4.840064]]
# Cost after iteration i: 838 [[4.84007117]]
# Cost after iteration i: 839 [[4.84007834]]
# Cost after iteration i: 840 [[4.84008551]]
# Cost after iteration i: 841 [[4.84009267]]
# Cost after iteration i: 842 [[4.84009982]]
# Cost after iteration i: 843 [[4.84010697]]
# Cost after iteration i: 844 [[4.84011412]]
# Cost after iteration i: 845 [[4.84012126]]
# Cost after iteration i: 846 [[4.84012839]]
# Cost after iteration i: 847 [[4.84013552]]
# Cost after iteration i: 848 [[4.84014264]]
# Cost after iteration i: 849 [[4.84014976]]
# Cost after iteration i: 850 [[4.84015688]]
# Cost after iteration i: 851 [[4.84016399]]
# Cost after iteration i: 852 [[4.84017109]]
# Cost after iteration i: 853 [[4.84017819]]
# Cost after iteration i: 854 [[4.84018528]]
# Cost after iteration i: 855 [[4.84019237]]
# Cost after iteration i: 856 [[4.84019945]]
# Cost after iteration i: 857 [[4.84020653]]
# Cost after iteration i: 858 [[4.8402136]]
# Cost after iteration i: 859 [[4.84022067]]
# Cost after iteration i: 860 [[4.84022773]]
# Cost after iteration i: 861 [[4.84023479]]
# Cost after iteration i: 862 [[4.84024185]]
# Cost after iteration i: 863 [[4.84024889]]
# Cost after iteration i: 864 [[4.84025594]]
# Cost after iteration i: 865 [[4.84026297]]
# Cost after iteration i: 866 [[4.84027001]]
# Cost after iteration i: 867 [[4.84027703]]
# Cost after iteration i: 868 [[4.84028406]]
# Cost after iteration i: 869 [[4.84029107]]
# Cost after iteration i: 870 [[4.84029809]]
# Cost after iteration i: 871 [[4.84030509]]
# Cost after iteration i: 872 [[4.8403121]]
# Cost after iteration i: 873 [[4.84031909]]
# Cost after iteration i: 874 [[4.84032609]]
# Cost after iteration i: 875 [[4.84033308]]
# Cost after iteration i: 876 [[4.84034006]]
# Cost after iteration i: 877 [[4.84034704]]
# Cost after iteration i: 878 [[4.84035401]]
# Cost after iteration i: 879 [[4.84036098]]
# Cost after iteration i: 880 [[4.84036794]]
# Cost after iteration i: 881 [[4.8403749]]
# Cost after iteration i: 882 [[4.84038185]]
# Cost after iteration i: 883 [[4.8403888]]
# Cost after iteration i: 884 [[4.84039574]]
# Cost after iteration i: 885 [[4.84040268]]
# Cost after iteration i: 886 [[4.84040961]]
# Cost after iteration i: 887 [[4.84041654]]
# Cost after iteration i: 888 [[4.84042347]]
# Cost after iteration i: 889 [[4.84043039]]
# Cost after iteration i: 890 [[4.8404373]]
# Cost after iteration i: 891 [[4.84044421]]
# Cost after iteration i: 892 [[4.84045111]]
# Cost after iteration i: 893 [[4.84045801]]
# Cost after iteration i: 894 [[4.84046491]]
# Cost after iteration i: 895 [[4.8404718]]
# Cost after iteration i: 896 [[4.84047868]]
# Cost after iteration i: 897 [[4.84048556]]
# Cost after iteration i: 898 [[4.84049244]]
# Cost after iteration i: 899 [[4.84049931]]
# Cost after iteration i: 900 [[4.84050617]]
# Cost after iteration i: 901 [[4.84051303]]
# Cost after iteration i: 902 [[4.84051989]]
# Cost after iteration i: 903 [[4.84052674]]
# Cost after iteration i: 904 [[4.84053359]]
# Cost after iteration i: 905 [[4.84054043]]
# Cost after iteration i: 906 [[4.84054726]]
# Cost after iteration i: 907 [[4.8405541]]
# Cost after iteration i: 908 [[4.84056092]]
# Cost after iteration i: 909 [[4.84056774]]
# Cost after iteration i: 910 [[4.84057456]]
# Cost after iteration i: 911 [[4.84058138]]
# Cost after iteration i: 912 [[4.84058818]]
# Cost after iteration i: 913 [[4.84059499]]
# Cost after iteration i: 914 [[4.84060179]]
# Cost after iteration i: 915 [[4.84060858]]
# Cost after iteration i: 916 [[4.84061537]]
# Cost after iteration i: 917 [[4.84062215]]
# Cost after iteration i: 918 [[4.84062893]]
# Cost after iteration i: 919 [[4.84063571]]
# Cost after iteration i: 920 [[4.84064248]]
# Cost after iteration i: 921 [[4.84064924]]
# Cost after iteration i: 922 [[4.840656]]
# Cost after iteration i: 923 [[4.84066276]]
# Cost after iteration i: 924 [[4.84066951]]
# Cost after iteration i: 925 [[4.84067626]]
# Cost after iteration i: 926 [[4.840683]]
# Cost after iteration i: 927 [[4.84068974]]
# Cost after iteration i: 928 [[4.84069647]]
# Cost after iteration i: 929 [[4.8407032]]
# Cost after iteration i: 930 [[4.84070992]]
# Cost after iteration i: 931 [[4.84071664]]
# Cost after iteration i: 932 [[4.84072336]]
# Cost after iteration i: 933 [[4.84073007]]
# Cost after iteration i: 934 [[4.84073677]]
# Cost after iteration i: 935 [[4.84074347]]
# Cost after iteration i: 936 [[4.84075017]]
# Cost after iteration i: 937 [[4.84075686]]
# Cost after iteration i: 938 [[4.84076354]]
# Cost after iteration i: 939 [[4.84077023]]
# Cost after iteration i: 940 [[4.8407769]]
# Cost after iteration i: 941 [[4.84078358]]
# Cost after iteration i: 942 [[4.84079024]]
# Cost after iteration i: 943 [[4.84079691]]
# Cost after iteration i: 944 [[4.84080357]]
# Cost after iteration i: 945 [[4.84081022]]
# Cost after iteration i: 946 [[4.84081687]]
# Cost after iteration i: 947 [[4.84082352]]
# Cost after iteration i: 948 [[4.84083016]]
# Cost after iteration i: 949 [[4.84083679]]
# Cost after iteration i: 950 [[4.84084342]]
# Cost after iteration i: 951 [[4.84085005]]
# Cost after iteration i: 952 [[4.84085667]]
# Cost after iteration i: 953 [[4.84086329]]
# Cost after iteration i: 954 [[4.84086991]]
# Cost after iteration i: 955 [[4.84087652]]
# Cost after iteration i: 956 [[4.84088312]]
# Cost after iteration i: 957 [[4.84088972]]
# Cost after iteration i: 958 [[4.84089632]]
# Cost after iteration i: 959 [[4.84090291]]
# Cost after iteration i: 960 [[4.84090949]]
# Cost after iteration i: 961 [[4.84091607]]
# Cost after iteration i: 962 [[4.84092265]]
# Cost after iteration i: 963 [[4.84092923]]
# Cost after iteration i: 964 [[4.84093579]]
# Cost after iteration i: 965 [[4.84094236]]
# Cost after iteration i: 966 [[4.84094892]]
# Cost after iteration i: 967 [[4.84095547]]
# Cost after iteration i: 968 [[4.84096202]]
# Cost after iteration i: 969 [[4.84096857]]
# Cost after iteration i: 970 [[4.84097511]]
# Cost after iteration i: 971 [[4.84098165]]
# Cost after iteration i: 972 [[4.84098818]]
# Cost after iteration i: 973 [[4.84099471]]
# Cost after iteration i: 974 [[4.84100124]]
# Cost after iteration i: 975 [[4.84100776]]
# Cost after iteration i: 976 [[4.84101427]]
# Cost after iteration i: 977 [[4.84102078]]
# Cost after iteration i: 978 [[4.84102729]]
# Cost after iteration i: 979 [[4.84103379]]
# Cost after iteration i: 980 [[4.84104029]]
# Cost after iteration i: 981 [[4.84104678]]
# Cost after iteration i: 982 [[4.84105327]]
# Cost after iteration i: 983 [[4.84105976]]
# Cost after iteration i: 984 [[4.84106624]]
# Cost after iteration i: 985 [[4.84107271]]
# Cost after iteration i: 986 [[4.84107918]]
# Cost after iteration i: 987 [[4.84108565]]
# Cost after iteration i: 988 [[4.84109211]]
# Cost after iteration i: 989 [[4.84109857]]
# Cost after iteration i: 990 [[4.84110503]]
# Cost after iteration i: 991 [[4.84111148]]
# Cost after iteration i: 992 [[4.84111792]]
# Cost after iteration i: 993 [[4.84112436]]
# Cost after iteration i: 994 [[4.8411308]]
# Cost after iteration i: 995 [[4.84113723]]
# Cost after iteration i: 996 [[4.84114366]]
# Cost after iteration i: 997 [[4.84115009]]
# Cost after iteration i: 998 [[4.84115651]]
# Cost after iteration i: 999 [[4.84116292]]

# %%
prediction_results = forward_propagate(X_train, W1, b1, W2, b2)

predictions = prediction_results['A2']

# for pred in range(predictions.shape[1]):
#     if predictions[:, pred] <= 0.5:
#         predictions[:, pred] = 0
#     else:
#         predictions[:, pred] = 1

train_pred = pd.DataFrame({'prediction': predictions.squeeze(),
              'actual': y_train.squeeze()
             })
print(train_pred.head(15))
# Out:
#      prediction  actual
# 60     0.009585       1
# 116    0.009863       2
# 144    0.009867       2
# 119    0.009843       2
# 108    0.009865       2
# 69     0.009779       1
# 135    0.009869       2
# 56     0.009855       1
# 80     0.009757       1
# 123    0.009854       2
# 133    0.009856       2
# 106    0.009772       2
# 146    0.009855       2
# 50     0.009862       1
# 147    0.009862       2

# %%
ave_err = np.sum(train_pred['prediction'] - train_pred['actual']) / len(train_pred)
ave_err
# Out:
# -1.0380952380952382

# %% [markdown]
# ### Test

# %%
test_prediction_results = forward_propagate(X_test, W1, b1, W2, b2)

test_predictions = test_prediction_results['A2']

for pred in range(test_predictions.shape[1]):
    if test_predictions[:, pred] <= 0.5:
        test_predictions[:, pred] = 0
    else:
        test_predictions[:, pred] = 1

test_pred = pd.DataFrame({'prediction': test_predictions.squeeze(),
              'actual': y_test.squeeze()
             })

print(test_pred)

ave_err = np.sum(test_pred['prediction'] - test_pred['actual']) / len(test_pred)
print('Average error: ', ave_err)
# Out:
#     prediction  actual
# 26         0.0       0
# 86         1.0       1
# 2          0.0       0
# 55         1.0       1
# 75         1.0       1
# 93         1.0       1
# 16         0.0       0
# 73         1.0       1
# 54         1.0       1
# 95         1.0       1
# 53         1.0       1
# 92         1.0       1
# 78         1.0       1
# 13         0.0       0
# 7          0.0       0
# 30         0.0       0
# 22         0.0       0
# 24         0.0       0
# 33         0.0       0
# 8          0.0       0
# 43         0.0       0
# 62         1.0       1
# 3          0.0       0
# 71         1.0       1
# 45         0.0       0
# 48         0.0       0
# 6          0.0       0
# 99         1.0       1
# 82         1.0       1
# 76         1.0       1
# Average error:  0.0
